# %%
class node:
    def __init__(self,data):
        self.data=data
        self.next=None
class linkedlist:
    def __init__(self):
        self.head=None
        
    def insert(self,data):
        newnode=node(data)
        if self.head is None:
            self.head=newnode
            return

        current_node = self.head
        while(current_node.next):
            current_node = current_node.next
 
        current_node.next = newnode
    def insertbeg(self,data):
        newnode=node(data)
        if self.head==None:
            self.head=newnode
            return
        
        else:
            newnode.next=self.head
            self.head=newnode
    
    def printl(self):
        temp=self.head
        while(temp):
            print(temp.data,"-->",end=" ")
            temp=temp.next
            
            
    def lcount(self):
        count=0
        temp=self.head
        
        while(temp):
            count+=1
            temp=temp.next
            
        return count
        
    """def middle(self,mid):
        count=0
        temp=self.head
        while(count<mid ):
            count+=1
            temp=temp.next
            
        print("-----------------------------------------------",temp.data) """
        
        
    def reverse(self):
        current=self.head
        temp=None
        
        while(current):
            next = current.next
            current.next = temp
            temp = current
            current = next
            
        self.head=temp
            
            
    def middle(self):
        slow=fast=self.head
        while(fast and fast.next):
            slow=slow.next
            fast=fast.next.next
            
        return slow.data
    
    def detectloop(self):
        slow=fast=self.head
        while(fast and fast.next):
            slow=slow.next
            fast=fast.next.next
            if(slow==fast):
                return True
                
        
        return Flase
            
            
        
    
    
Llist=linkedlist()
Llist.insert(1)
Llist.insert(2)
Llist.insert(3)
Llist.insert(4)
Llist.insert(5)
Llist.insert(6)
Llist.insertbeg(9)
Llist.insertbeg(10)
Llist.printl()

print()
length=Llist.lcount()
print(" the legth of linked list is ",length)
mid=length//2 + 1
print(mid)
middle=Llist.middle()
print("the middle element is  ",middle)

print("--------------------------------------------------------------------------------------------")
Llist.reverse()
Llist.printl()
# Out:
# 10 --> 9 --> 1 --> 2 --> 3 --> 4 --> 5 --> 6 -->
#  the legth of linked list is  8
# 5
# the middle element is   3
# --------------------------------------------------------------------------------------------
# 6 --> 5 --> 4 --> 3 --> 2 --> 1 --> 9 --> 10 -->

# %%
class node:
    def __init__(self,data):
        self.data=data
        self.next=None
class linkedlist:
    def __init__(self):
        self.head=None
        
    def insert(self,data):
        newnode=node(data)
        if self.head is None:
            self.head=newnode
            return

        current_node = self.head
        while(current_node.next):
            current_node = current_node.next
 
        current_node.next = newnode
    def insertbeg(self,data):
        newnode=node(data)
        if self.head==None:
            self.head=newnode
            return
        
        else:
            newnode.next=self.head
            self.head=newnode
    
    def printl(self):
        temp=self.head
        while(temp):
            print(temp.data,"-->",end=" ")
            temp=temp.next
            
            
    def detectLoop(self):
        slow=fast=self.head
        while(fast and fast.next):
            slow=slow.next
            fast=fast.next.next
            if(slow==fast):
                while(slow !=fast):
                    slow=slow.next
                    fast=fast.next
                return slow.data
        
        return False
            
            
        
    
    
Llist=linkedlist()
Llist.insert(1)
Llist.insert(2)
Llist.insert(3)
Llist.insert(4)
Llist.insert(5)
Llist.insert(6)
Llist.insertbeg(9)
Llist.printl()

print()

Llist.head.next.next.next.next = Llist.head.next.next.next
 
loop=Llist.detectLoop()
print(loop)
print("------------------------")
# Out:
# 9 --> 1 --> 2 --> 3 --> 4 --> 5 --> 6 -->
# 3
# ------------------------
